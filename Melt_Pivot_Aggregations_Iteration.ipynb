# %%
import pandas as pd 
import numpy as np

# %%
diabetic_df = pd.read_csv('diabetic_data.csv')
diabetic_df.head()
# Out:
#    encounter_id  patient_nbr             race  gender      age weight  \
# 0       2278392      8222157        Caucasian  Female   [0-10)      ?
# 1        149190     55629189        Caucasian  Female  [10-20)      ?
# 2         64410     86047875  AfricanAmerican  Female  [20-30)      ?
# 3        500364     82442376        Caucasian    Male  [30-40)      ?
# 4         16680     42519267        Caucasian    Male  [40-50)      ?
#
#    admission_type_id  discharge_disposition_id  admission_source_id  \
# 0                  6                        25                    1
# 1                  1                         1                    7
# 2                  1                         1                    7
# 3                  1                         1                    7
# 4                  1                         1                    7
#
#    time_in_hospital  ... citoglipton insulin  glyburide-metformin  \
# ...

# %%
#Melt
diabetic_melt = pd.melt(diabetic_df, id_vars=['patient_nbr'], value_vars=['diabetesMed'], var_name = 'Diabetes Medication') 
#melting the patient number, as this identifies each individual patient, alongside the diabetesMed column to understand how the particular patient is related to the diabetesMed column

# %%
print(diabetic_melt)
# Out:
#         patient_nbr Diabetes Medication value
# 0           8222157         diabetesMed    No
# 1          55629189         diabetesMed   Yes
# 2          86047875         diabetesMed   Yes
# 3          82442376         diabetesMed   Yes
# 4          42519267         diabetesMed   Yes
# ...             ...                 ...   ...
# 101761    100162476         diabetesMed   Yes
# 101762     74694222         diabetesMed   Yes
# 101763     41088789         diabetesMed   Yes
# 101764     31693671         diabetesMed   Yes
# 101765    175429310         diabetesMed    No
#
# [101766 rows x 3 columns]

# %%
#Pivot
diabetic_pivot = diabetic_df.pivot(values = 'number_diagnoses', index = 'encounter_id', columns = 'readmitted')
#applying pivot table method to understand how the number of diagnoses is related to readmission for individual encounters
print(diabetic_pivot)
# Out:
# readmitted    <30  >30    NO
# encounter_id
# 12522         NaN  NaN   8.0
# 15738         NaN  NaN   8.0
# 16680         NaN  NaN   5.0
# 28236         NaN  9.0   NaN
# 35754         NaN  9.0   NaN
# ...           ...  ...   ...
# 443847548     NaN  9.0   NaN
# 443847782     NaN  NaN   9.0
# 443854148     NaN  NaN  13.0
# 443857166     NaN  NaN   9.0
# 443867222     NaN  NaN   9.0
#
# [101766 rows x 3 columns]

# %%
#Aggregation
diabetic_agg = diabetic_df.aggregate({'time_in_hospital':['mean','min','max'], 'num_lab_procedures':['mean','min','max'], 'num_medications': ['mean','min','max']})
#using aggregation to understand how the time spent in the hospital may correlate to the number of lab procedures done and medications the patients takes 
#utilizing the mean, min and max of the variables 
print(diabetic_agg)
# Out:
#       time_in_hospital  num_lab_procedures  num_medications
# mean          4.395987           43.095641        16.021844
# min           1.000000            1.000000         1.000000
# max          14.000000          132.000000        81.000000

# %%
#Itteration
for index, row in diabetic_df.iterrows(): #using iterrow to itterate through the 'race' column in the dataset - this repeatedly executes each race in the dataset
    print(row['race'])
# Out:
# Caucasian
# Caucasian
# AfricanAmerican
# Caucasian
# Caucasian
# Caucasian
# Caucasian
# Caucasian
# Caucasian
# Caucasian
# AfricanAmerican
# AfricanAmerican
# Caucasian
# Caucasian
# AfricanAmerican
# AfricanAmerican
# AfricanAmerican
# Caucasian
# AfricanAmerican
# ?
# ?
# ?
# AfricanAmerican
# Caucasian
# AfricanAmerican
# Other
# Caucasian
# Caucasian
# Caucasian
# Caucasian
# AfricanAmerican
# AfricanAmerican
# Caucasian
# Caucasian
# Caucasian
# Caucasian
# Caucasian
# Caucasian
# Caucasian
# Caucasian
# Caucasian
# Caucasian
# Caucasian
# Caucasian
# Caucasian
# Caucasian
# Caucasian
# Caucasian
# Caucasian
# Caucasian
# AfricanAmerican
# Caucasian
# AfricanAmerican
# AfricanAmerican
# ?
# Caucasian
# AfricanAmerican
# Caucasian
# AfricanAmerican
# Caucasian
# AfricanAmerican
# Caucasian
# AfricanAmerican
# Caucasian
# AfricanAmerican
# ?
# Caucasian
# Caucasian
# Caucasian
# Caucasian
# Caucasian
# Caucasian
# Caucasian
# Caucasian
# Caucasian
# Caucasian
# AfricanAmerican
# ...

# %%
#Group By
diabetes_groupby = diabetic_df.groupby('gender') #this step actually groups the chosen column
diabetes_groupby.describe() #this step aggregates, in this case using describe method, which outputs various descriptions as seen in the table output
# Out:
#                 encounter_id                                          \
#                        count          mean           std         min
# gender
# Female               54708.0  1.646297e+08  1.020601e+08     12522.0
# Male                 47055.0  1.658648e+08  1.033094e+08     16680.0
# Unknown/Invalid          3.0  1.942879e+08  8.422999e+07  98634858.0
#
#                                                                      \
#                          25%          50%          75%          max
# gender
# Female            85501090.5  151882362.0  228864438.0  443857166.0
# Male              84370632.0  152886924.0  231841734.0  443867222.0
# Unknown/Invalid  162749763.0  226864668.0  242114481.0  257364294.0
#
#                 patient_nbr                ... number_inpatient        \
#                       count          mean  ...              75%   max
# gender                                     ...
# ...
